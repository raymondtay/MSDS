# %% [markdown]
# Simulation is a great tool for probability problems even when you are trying to compute exact results since it can help you to check your work!

# %% [markdown]
# # Problem 1

# %% [markdown]
# Suppose you roll a fair six-sided die two times. Let $A$ be the event "the sum of the throws equals 5" and $B$ be the event "at least one of the throws is a $4$".

# %% [markdown]
# **Part a)**
#
# By hand, solve for the probability that the sum of the throws equals 5, given that at least one of the throws is a 4. That is, solve $P(A|B)$.

# %% [markdown]
# **Part b)**
#
# In the next cell, write a simple simulation to confirm your result. Make sure you run your simulation enough times to be confident in your result. We will get you started but <b>feel free to delete the provided code to use your own approach</b>.
#
# Hint: Think about the definition of conditional probability.

# %%
# Your code here

rolls <- expand.grid(d1 = 1:6, d2 = 1:6)
A <- subset(rolls, d1+d2 == 5)
B <- subset(rolls, d1 == 4 | d2 == 4)

A_and_B <- merge(A, B)
P_A <- nrow(A) / nrow(rolls)
P_B <- nrow(B) / nrow(rolls)
P_A_and_P_B <- nrow(A_and_B) / nrow(rolls)

P_A_given_P_B <- P_A_and_P_B / P_B

cat("P(A): ", P_A, "\n")
cat("P(B): ", P_B, "\n")
cat("P(A n B): ", P_A_and_P_B, "\n")
cat("P(A | B): ", P_A_given_P_B, "\n")
# Out:
# P(A):  0.1111111
# P(B):  0.3055556
# P(A n B):  0.05555556
# P(A | B):  0.1818182

# %% [markdown]
# <hr>

# %% [markdown]
# # Problem 2
#
# Suppose you have two bags of marbles that are in a box. Bag 1 contains 7 white marbles, 6 black marbles, and 3 gold marbles. Bag 2 contains 4 white marbles, 5 black marbles, and 15 gold marbles. You will reach into the box to pull out a bag. Suppose that, due to the size and shapes of the bags, the probability of grabbing Bag 1 from the box is twice the probability of grabbing Bag 2.
#
# If you close your eyes, grab a bag from the box, and then grab a marble from that bag, what is the probability that it is gold?

# %% [markdown]
# **Part a)**
#
# Solve this problem by hand. This should give us a theoretical value for pulling a gold marble.

# %% [markdown]
# **Part b)**
#
# Create a simulation to estimate the probability of pulling a gold marble. Make sure to run the simulation enough times to be confident in your final result!
#
# Hint: You can sample one marble from Bag 1 with this line of code
#
# <code>sample(c("white","black","gold"),1,prob=c(7/16,6/16,3/16))</code>
#
# though you mind find it easier to label white marbles as "1", black marbles as "2", and gold marbles as "3" rather than having to work with strings.

# %%
# Your code here

set.seed(42)
simulate <- function(n = 1e2) {
  results <- replicate(n, {
    # step 1: pick a bag
    P_Bag <- sample(c(1,2), 1, prob = c(2/3, 1/3))

    marble <- if (P_Bag == 1) {
      P_Bag1 <- sample(c("white", "black", "gold"), 1, prob = c(7/16, 6/16, 3/16))
      cat("P(Gold | Bag1): ", P_Bag1, "\n")
      P_Bag1
    } else {
      P_Bag2 <- sample(c("white", "black", "gold"), 1, prob = c(4/24, 5/24, 15/24))
      cat("P(Gold | Bag2): ", P_Bag2, "\n")
      P_Bag2
    }
    marble == "gold"
})
}

simulate()
# Out:
# P(Gold | Bag2):  white
# P(Gold | Bag1):  gold
# P(Gold | Bag1):  black
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  black
# P(Gold | Bag1):  black
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  gold
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  black
# P(Gold | Bag2):  gold
# P(Gold | Bag2):  white
# P(Gold | Bag1):  black
# P(Gold | Bag1):  gold
# P(Gold | Bag1):  gold
# P(Gold | Bag2):  black
# P(Gold | Bag1):  black
# P(Gold | Bag1):  gold
# P(Gold | Bag1):  white
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  white
# P(Gold | Bag1):  gold
# P(Gold | Bag1):  gold
# P(Gold | Bag2):  black
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  white
# P(Gold | Bag1):  black
# P(Gold | Bag1):  black
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  black
# P(Gold | Bag2):  white
# P(Gold | Bag2):  gold
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  gold
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  white
# P(Gold | Bag1):  black
# P(Gold | Bag1):  black
# P(Gold | Bag1):  white
# P(Gold | Bag1):  white
# P(Gold | Bag1):  white
# P(Gold | Bag1):  black
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  white
# P(Gold | Bag1):  white
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  gold
# P(Gold | Bag2):  black
# P(Gold | Bag1):  black
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  white
# P(Gold | Bag1):  white
# P(Gold | Bag2):  white
# P(Gold | Bag2):  black
# P(Gold | Bag1):  white
# P(Gold | Bag1):  gold
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  black
# P(Gold | Bag1):  white
# P(Gold | Bag1):  gold
# P(Gold | Bag1):  white
# P(Gold | Bag1):  black
# P(Gold | Bag2):  gold
# P(Gold | Bag2):  white
# P(Gold | Bag1):  black
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  gold
# P(Gold | Bag2):  gold
# P(Gold | Bag2):  gold
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  white
# P(Gold | Bag1):  black
# P(Gold | Bag2):  black
# P(Gold | Bag1):  gold
# P(Gold | Bag1):  white
# P(Gold | Bag2):  gold
# P(Gold | Bag2):  gold
# P(Gold | Bag2):  black
# P(Gold | Bag1):  white
# P(Gold | Bag1):  black
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  white
# P(Gold | Bag1):  white
# P(Gold | Bag1):  white
# P(Gold | Bag1):  white
# P(Gold | Bag2):  gold
# P(Gold | Bag1):  black
# P(Gold | Bag1):  white
# P(Gold | Bag2):  gold
# P(Gold | Bag2):  black
# P(Gold | Bag2):  white
# P(Gold | Bag1):  white
# P(Gold | Bag2):  black
# P(Gold | Bag2):  black
# P(Gold | Bag1):  white
# P(Gold | Bag1):  black
# P(Gold | Bag1):  white
# P(Gold | Bag1):  white
# P(Gold | Bag1):  white
# P(Gold | Bag2):  black
